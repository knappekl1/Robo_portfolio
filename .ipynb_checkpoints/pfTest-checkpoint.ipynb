# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {"return":[0.12,0.108, 0.06], "var":[0.034, 0.0293, 0.0098]}

# %%
df = pd.DataFrame(data, index=["A","B","C"])

# %%
df
# Out:
#    return     var
# A   0.120  0.0340
# B   0.108  0.0293
# C   0.060  0.0098

# %%
w = np.array([0.5, 0.25, 0.25])

# %%
w
# Out:
# array([0.5 , 0.25, 0.25])

# %%
cov = np.array([[0.034,0.0126,0.0045],[0.0126,0.0293,0.013],[0.0045,0.013,0.0098]])

# %%
cov
# Out:
# array([[0.034 , 0.0126, 0.0045],
#        [0.0126, 0.0293, 0.013 ],
#        [0.0045, 0.013 , 0.0098]])

# %%
cov_matrix = pd.DataFrame(cov, index=["A","B","C"], columns=["A","B","C"])

# %%
cov_matrix
# Out:
#         A       B       C
# A  0.0340  0.0126  0.0045
# B  0.0126  0.0293  0.0130
# C  0.0045  0.0130  0.0098

# %%
ret = np.matmul(w,df["return"].transpose())

# %%
ret
# Out:
# 0.102

# %%
df["return"].mean()
# Out:
# 0.09599999999999999

# %%
pf_var = cov_matrix.mul(w, axis=0).mul(w, axis=1).sum().sum()

# %%
pf_var
# Out:
# 0.01684375

# %%
pf_ret = []
pf_std = []
for n in range(10000):
    w = np.random.rand(len(df))
    w = w / w.sum()
    if np.round(w.sum(),2) != 1:
        print(w.sum())
        break
    ret = np.matmul(w,df["return"].transpose())
    var = cov_matrix.mul(w, axis=0).mul(w, axis=1).sum().sum()
    pf_ret.append(ret)
    pf_std.append(var**(1/2))

data = {"ret":pf_ret,"std":pf_std}

# %%
result = pd.DataFrame(data)

# %%
result.plot.scatter("std","ret", alpha=0.3,s=2,figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='std', ylabel='ret'>
